# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
from pprint import pprint
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weath_desc = city_weather["weather"][0]["description"]  
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Current Description": city_weath_desc,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country})
   
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
    # Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | sampit
# Processing Record 3 of Set 1 | mnogovershinnyy
# Processing Record 4 of Set 1 | oussouye
# Processing Record 5 of Set 1 | constitucion
# Processing Record 6 of Set 1 | iquitos
# Processing Record 7 of Set 1 | porto novo
# Processing Record 8 of Set 1 | ancud
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | kruisfontein
# Processing Record 11 of Set 1 | rafai
# Processing Record 12 of Set 1 | fomboni
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | clyde river
# Processing Record 16 of Set 1 | uruzgan
# Processing Record 17 of Set 1 | pacific grove
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | kaitangata
# Processing Record 21 of Set 1 | kenai
# Processing Record 22 of Set 1 | yavaros
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | chuy
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | port blair
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | talcahuano
# Processing Record 34 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 1 | hobyo
# Processing Record 36 of Set 1 | coquimbo
# Processing Record 37 of Set 1 | makakilo city
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | pauini
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | neenah
# Processing Record 42 of Set 1 | ninghai
# Processing Record 43 of Set 1 | divnogorsk
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | nipawin
# Processing Record 47 of Set 1 | kahului
# Processing Record 48 of Set 1 | broken hill
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | upernavik
# Processing Record 1 of Set 2 | inuvik
# Processing Record 2 of Set 2 | dingle
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 4 of Set 2 | san jose
# Processing Record 5 of Set 2 | huntingdon
# Processing Record 6 of Set 2 | bastia
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | morondava
# Processing Record 9 of Set 2 | pisco
# Processing Record 10 of Set 2 | cayenne
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | tamale
# Processing Record 13 of Set 2 | kralendijk
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | kang
# Processing Record 16 of Set 2 | pyapon
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | hami
# Processing Record 19 of Set 2 | changji
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | norman wells
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | geraldton
# Processing Record 25 of Set 2 | anahuac
# Processing Record 26 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | mumford
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | shumskiy
# Processing Record 31 of Set 2 | prainha
# Processing Record 32 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 2 | preeceville
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | rubizhne
# Processing Record 36 of Set 2 | hasaki
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | antalaha
# Processing Record 39 of Set 2 | atar
# Processing Record 40 of Set 2 | richard toll
# City not found. Skipping...
# Processing Record 41 of Set 2 | saint george
# Processing Record 42 of Set 2 | cap malheureux
# Processing Record 43 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 2 | paamiut
# Processing Record 45 of Set 2 | portland
# Processing Record 46 of Set 2 | zeya
# Processing Record 47 of Set 2 | vardo
# Processing Record 48 of Set 2 | larap
# Processing Record 49 of Set 2 | atuona
# Processing Record 50 of Set 2 | mitsamiouli
# Processing Record 1 of Set 3 | codrington
# Processing Record 2 of Set 3 | cape town
# Processing Record 3 of Set 3 | belyy yar
# Processing Record 4 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 3 | port augusta
# Processing Record 6 of Set 3 | bahia honda
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | hithadhoo
# Processing Record 9 of Set 3 | north bend
# Processing Record 10 of Set 3 | kharitonovo
# Processing Record 11 of Set 3 | saint-joseph
# Processing Record 12 of Set 3 | rajgarh
# Processing Record 13 of Set 3 | cherskiy
# Processing Record 14 of Set 3 | hilo
# Processing Record 15 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 3 | rokytne
# Processing Record 17 of Set 3 | haimen
# Processing Record 18 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 3 | saldanha
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | zyryanovsk
# Processing Record 22 of Set 3 | egvekinot
# Processing Record 23 of Set 3 | oyama
# Processing Record 24 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 3 | shetpe
# Processing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 3 | ponta delgada
# Processing Record 28 of Set 3 | zverinogolovskoye
# Processing Record 29 of Set 3 | antigonish
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | bataipora
# Processing Record 32 of Set 3 | rawson
# Processing Record 33 of Set 3 | yunhe
# Processing Record 34 of Set 3 | katsuura
# Processing Record 35 of Set 3 | isangel
# Processing Record 36 of Set 3 | chokurdakh
# Processing Record 37 of Set 3 | north myrtle beach
# Processing Record 38 of Set 3 | ugoofaaru
# Processing Record 39 of Set 3 | aragats
# Processing Record 40 of Set 3 | sun city west
# Processing Record 41 of Set 3 | faya
# Processing Record 42 of Set 3 | slyudyanka
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | camacha
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | rantepao
# Processing Record 47 of Set 3 | provideniya
# Processing Record 48 of Set 3 | yulara
# Processing Record 49 of Set 3 | chapais
# Processing Record 50 of Set 3 | gobabis
# Processing Record 1 of Set 4 | bluff
# Processing Record 2 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 3 of Set 4 | khanpur
# Processing Record 4 of Set 4 | shieli
# Processing Record 5 of Set 4 | jingdezhen
# Processing Record 6 of Set 4 | merauke
# Processing Record 7 of Set 4 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 8 of Set 4 | boa vista
# Processing Record 9 of Set 4 | nikolskoye
# Processing Record 10 of Set 4 | lazaro cardenas
# Processing Record 11 of Set 4 | lask
# Processing Record 12 of Set 4 | broome
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | lensk
# Processing Record 15 of Set 4 | lasa
# Processing Record 16 of Set 4 | clearlake
# Processing Record 17 of Set 4 | bilma
# Processing Record 18 of Set 4 | yarada
# Processing Record 19 of Set 4 | vao
# Processing Record 20 of Set 4 | saint-pierre
# Processing Record 21 of Set 4 | tashtagol
# Processing Record 22 of Set 4 | byron bay
# Processing Record 23 of Set 4 | saint anthony
# Processing Record 24 of Set 4 | mersing
# Processing Record 25 of Set 4 | sinop
# Processing Record 26 of Set 4 | shimoda
# Processing Record 27 of Set 4 | bengkulu
# Processing Record 28 of Set 4 | zyryanka
# Processing Record 29 of Set 4 | cuauhtemoc
# Processing Record 30 of Set 4 | fortuna
# Processing Record 31 of Set 4 | vidyayevo
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | kuala terengganu
# Processing Record 34 of Set 4 | mandalgovi
# Processing Record 35 of Set 4 | san cristobal
# Processing Record 36 of Set 4 | ahipara
# Processing Record 37 of Set 4 | kita
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | palmer
# Processing Record 40 of Set 4 | matsanga
# City not found. Skipping...
# Processing Record 41 of Set 4 | bagado
# Processing Record 42 of Set 4 | salalah
# Processing Record 43 of Set 4 | dicabisagan
# Processing Record 44 of Set 4 | nuuk
# Processing Record 45 of Set 4 | tucupita
# Processing Record 46 of Set 4 | stokmarknes
# Processing Record 47 of Set 4 | mahebourg
# Processing Record 48 of Set 4 | kindu
# Processing Record 49 of Set 4 | el balyana
# City not found. Skipping...
# Processing Record 50 of Set 4 | henties bay
# Processing Record 1 of Set 5 | adrar
# Processing Record 2 of Set 5 | porto santo
# Processing Record 3 of Set 5 | chibombo
# Processing Record 4 of Set 5 | itarema
# Processing Record 5 of Set 5 | la ronge
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | vanavara
# Processing Record 8 of Set 5 | port lincoln
# Processing Record 9 of Set 5 | beyneu
# Processing Record 10 of Set 5 | bandarbeyla
# Processing Record 11 of Set 5 | oum hadjer
# Processing Record 12 of Set 5 | lagoa
# Processing Record 13 of Set 5 | farafangana
# Processing Record 14 of Set 5 | hambantota
# Processing Record 15 of Set 5 | manaure
# Processing Record 16 of Set 5 | iqaluit
# Processing Record 17 of Set 5 | bethel
# Processing Record 18 of Set 5 | wadi maliz
# Processing Record 19 of Set 5 | parung
# Processing Record 20 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 5 | koppal
# Processing Record 22 of Set 5 | acapulco
# Processing Record 23 of Set 5 | port hardy
# Processing Record 24 of Set 5 | georgetown
# Processing Record 25 of Set 5 | alofi
# Processing Record 26 of Set 5 | cabo san lucas
# Processing Record 27 of Set 5 | quinabigan
# Processing Record 28 of Set 5 | lebu
# Processing Record 29 of Set 5 | yerbogachen
# Processing Record 30 of Set 5 | sicuani
# Processing Record 31 of Set 5 | whitehorse
# Processing Record 32 of Set 5 | bukachacha
# Processing Record 33 of Set 5 | mandera
# Processing Record 34 of Set 5 | richards bay
# Processing Record 35 of Set 5 | kapit
# Processing Record 36 of Set 5 | havelock
# Processing Record 37 of Set 5 | namatanai
# Processing Record 38 of Set 5 | nome
# Processing Record 39 of Set 5 | karakol
# Processing Record 40 of Set 5 | lethem
# Processing Record 41 of Set 5 | vargashi
# Processing Record 42 of Set 5 | saint-philippe
# Processing Record 43 of Set 5 | hurghada
# Processing Record 44 of Set 5 | aklavik
# Processing Record 45 of Set 5 | bodden town
# Processing Record 46 of Set 5 | urusha
# Processing Record 47 of Set 5 | riom
# Processing Record 48 of Set 5 | manali
# Processing Record 49 of Set 5 | kudahuvadhoo
# Processing Record 50 of Set 5 | kurchum
# Processing Record 1 of Set 6 | severo-kurilsk
# Processing Record 2 of Set 6 | atambua
# Processing Record 3 of Set 6 | banda aceh
# Processing Record 4 of Set 6 | partapur
# Processing Record 5 of Set 6 | ilulissat
# Processing Record 6 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 6 | piacabucu
# Processing Record 8 of Set 6 | the valley
# Processing Record 9 of Set 6 | prince rupert
# Processing Record 10 of Set 6 | bethanien
# Processing Record 11 of Set 6 | san quintin
# Processing Record 12 of Set 6 | viedma
# Processing Record 13 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 6 | maumere
# Processing Record 15 of Set 6 | rameswaram
# Processing Record 16 of Set 6 | chikwawa
# Processing Record 17 of Set 6 | kutum
# Processing Record 18 of Set 6 | dakar
# Processing Record 19 of Set 6 | porto murtinho
# Processing Record 20 of Set 6 | wageningen
# Processing Record 21 of Set 6 | maragogi
# Processing Record 22 of Set 6 | nieuw nickerie
# Processing Record 23 of Set 6 | banmo
# City not found. Skipping...
# Processing Record 24 of Set 6 | sovetsk
# Processing Record 25 of Set 6 | nelson bay
# Processing Record 26 of Set 6 | sanica
# Processing Record 27 of Set 6 | khatanga
# Processing Record 28 of Set 6 | talen
# Processing Record 29 of Set 6 | tabas
# Processing Record 30 of Set 6 | ajaccio
# Processing Record 31 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 32 of Set 6 | port-cartier
# Processing Record 33 of Set 6 | ariquemes
# Processing Record 34 of Set 6 | rio gallegos
# Processing Record 35 of Set 6 | nioro
# Processing Record 36 of Set 6 | edinburg
# Processing Record 37 of Set 6 | tautira
# Processing Record 38 of Set 6 | colac
# Processing Record 39 of Set 6 | burnie
# Processing Record 40 of Set 6 | bambous virieux
# Processing Record 41 of Set 6 | caravelas
# Processing Record 42 of Set 6 | kiunga
# Processing Record 43 of Set 6 | atasu
# Processing Record 44 of Set 6 | tlahualilo
# City not found. Skipping...
# Processing Record 45 of Set 6 | varzea grande
# Processing Record 46 of Set 6 | luganville
# Processing Record 47 of Set 6 | estevan
# Processing Record 48 of Set 6 | ibotirama
# Processing Record 49 of Set 6 | kerrville
# Processing Record 50 of Set 6 | yaan
# Processing Record 1 of Set 7 | bowen
# Processing Record 2 of Set 7 | esperance
# Processing Record 3 of Set 7 | barguzin
# Processing Record 4 of Set 7 | mareeba
# Processing Record 5 of Set 7 | salinopolis
# Processing Record 6 of Set 7 | lata
# Processing Record 7 of Set 7 | coos bay
# Processing Record 8 of Set 7 | santa cecilia
# Processing Record 9 of Set 7 | alenquer
# Processing Record 10 of Set 7 | cidreira
# Processing Record 11 of Set 7 | flinders
# Processing Record 12 of Set 7 | along
# Processing Record 13 of Set 7 | coihaique
# Processing Record 14 of Set 7 | ondjiva
# Processing Record 15 of Set 7 | surt
# Processing Record 16 of Set 7 | olinda
# Processing Record 17 of Set 7 | eina
# Processing Record 18 of Set 7 | loa janan
# Processing Record 19 of Set 7 | morlenbach
# Processing Record 20 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 7 | vila franca do campo
# Processing Record 22 of Set 7 | sao felix do xingu
# Processing Record 23 of Set 7 | las vegas
# Processing Record 24 of Set 7 | methoni
# Processing Record 25 of Set 7 | gazojak
# Processing Record 26 of Set 7 | chimoio
# Processing Record 27 of Set 7 | ankang
# Processing Record 28 of Set 7 | pilar
# Processing Record 29 of Set 7 | lompoc
# Processing Record 30 of Set 7 | coahuayana
# Processing Record 31 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 32 of Set 7 | husavik
# Processing Record 33 of Set 7 | gigant
# Processing Record 34 of Set 7 | narsaq
# Processing Record 35 of Set 7 | naze
# Processing Record 36 of Set 7 | shelburne
# Processing Record 37 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 7 | zhuhai
# Processing Record 39 of Set 7 | marawi
# Processing Record 40 of Set 7 | mount pleasant
# Processing Record 41 of Set 7 | luanda
# Processing Record 42 of Set 7 | ndele
# Processing Record 43 of Set 7 | maarianhamina
# Processing Record 44 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 7 | kalyan
# Processing Record 46 of Set 7 | alta floresta
# Processing Record 47 of Set 7 | san juan
# Processing Record 48 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 49 of Set 7 | bac lieu
# Processing Record 50 of Set 7 | awbari
# Processing Record 1 of Set 8 | muncar
# Processing Record 2 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 3 of Set 8 | saint-paul
# Processing Record 4 of Set 8 | bontang
# Processing Record 5 of Set 8 | talnakh
# Processing Record 6 of Set 8 | clearwater
# Processing Record 7 of Set 8 | foz
# Processing Record 8 of Set 8 | leningradskiy
# Processing Record 9 of Set 8 | maamba
# Processing Record 10 of Set 8 | margate
# Processing Record 11 of Set 8 | amursk
# Processing Record 12 of Set 8 | tongchuan
# Processing Record 13 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 8 | namibe
# Processing Record 15 of Set 8 | khasan
# Processing Record 16 of Set 8 | galanta
# Processing Record 17 of Set 8 | lebyazhye
# Processing Record 18 of Set 8 | ushtobe
# Processing Record 19 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 8 | maykain
# City not found. Skipping...
# Processing Record 21 of Set 8 | klaksvik
# Processing Record 22 of Set 8 | longyearbyen
# Processing Record 23 of Set 8 | prokuplje
# Processing Record 24 of Set 8 | tezu
# Processing Record 25 of Set 8 | muleba
# Processing Record 26 of Set 8 | ust-charyshskaya pristan
# Processing Record 27 of Set 8 | winnetka
# Processing Record 28 of Set 8 | faanui
# Processing Record 29 of Set 8 | muzhi
# Processing Record 30 of Set 8 | portage
# Processing Record 31 of Set 8 | carutapera
# Processing Record 32 of Set 8 | pedernales
# Processing Record 33 of Set 8 | marsaxlokk
# Processing Record 34 of Set 8 | langxiang
# Processing Record 35 of Set 8 | thunder bay
# Processing Record 36 of Set 8 | narrabri
# Processing Record 37 of Set 8 | bonavista
# Processing Record 38 of Set 8 | portel
# Processing Record 39 of Set 8 | anito
# Processing Record 40 of Set 8 | nador
# Processing Record 41 of Set 8 | sao joao da barra
# Processing Record 42 of Set 8 | pahrump
# Processing Record 43 of Set 8 | owando
# Processing Record 44 of Set 8 | hofn
# Processing Record 45 of Set 8 | amuntai
# Processing Record 46 of Set 8 | mount gambier
# Processing Record 47 of Set 8 | abnub
# Processing Record 48 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 49 of Set 8 | kamloops
# Processing Record 50 of Set 8 | santa isabel do rio negro
# Processing Record 1 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 9 | ostrovnoy
# Processing Record 3 of Set 9 | moa
# Processing Record 4 of Set 9 | meulaboh
# Processing Record 5 of Set 9 | primorsko-akhtarsk
# Processing Record 6 of Set 9 | pangody
# Processing Record 7 of Set 9 | zhezkazgan
# Processing Record 8 of Set 9 | laguna
# Processing Record 9 of Set 9 | jumla
# Processing Record 10 of Set 9 | venado tuerto
# Processing Record 11 of Set 9 | havoysund
# Processing Record 12 of Set 9 | comodoro rivadavia
# Processing Record 13 of Set 9 | mawlaik
# Processing Record 14 of Set 9 | gari
# Processing Record 15 of Set 9 | beckley
# Processing Record 16 of Set 9 | la guacamaya
# Processing Record 17 of Set 9 | shihezi
# Processing Record 18 of Set 9 | grindavik
# Processing Record 19 of Set 9 | banyo
# Processing Record 20 of Set 9 | el dorado
# Processing Record 21 of Set 9 | pevek
# Processing Record 22 of Set 9 | pimentel
# Processing Record 23 of Set 9 | at-bashi
# Processing Record 24 of Set 9 | guerrero negro
# Processing Record 25 of Set 9 | anadyr
# Processing Record 26 of Set 9 | komsomolskiy
# Processing Record 27 of Set 9 | port macquarie
# Processing Record 28 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 9 | ibra
# Processing Record 30 of Set 9 | katherine
# Processing Record 31 of Set 9 | progreso
# Processing Record 32 of Set 9 | dudinka
# Processing Record 33 of Set 9 | nyurba
# Processing Record 34 of Set 9 | roanoke
# Processing Record 35 of Set 9 | sur
# Processing Record 36 of Set 9 | lima
# Processing Record 37 of Set 9 | samarai
# Processing Record 38 of Set 9 | naples
# Processing Record 39 of Set 9 | harper
# Processing Record 40 of Set 9 | pawayan
# Processing Record 41 of Set 9 | llandrindod wells
# Processing Record 42 of Set 9 | airai
# Processing Record 43 of Set 9 | pitimbu
# Processing Record 44 of Set 9 | tilichiki
# Processing Record 45 of Set 9 | japura
# Processing Record 46 of Set 9 | cervo
# Processing Record 47 of Set 9 | luderitz
# Processing Record 48 of Set 9 | cockburn town
# Processing Record 49 of Set 9 | sitka
# Processing Record 50 of Set 9 | bahia blanca
# Processing Record 1 of Set 10 | tombouctou
# Processing Record 2 of Set 10 | westport
# Processing Record 3 of Set 10 | tigil
# Processing Record 4 of Set 10 | simbahan
# Processing Record 5 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 10 | paragominas
# Processing Record 7 of Set 10 | matveyev kurgan
# Processing Record 8 of Set 10 | beringovskiy
# Processing Record 9 of Set 10 | gaoua
# Processing Record 10 of Set 10 | nishihara
# Processing Record 11 of Set 10 | kannur
# Processing Record 12 of Set 10 | tuatapere
# Processing Record 13 of Set 10 | puerto del rosario
# Processing Record 14 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 10 | motygino
# Processing Record 16 of Set 10 | natal
# Processing Record 17 of Set 10 | deputatskiy
# Processing Record 18 of Set 10 | gushikawa
# Processing Record 19 of Set 10 | wuning
# Processing Record 20 of Set 10 | sinazongwe
# Processing Record 21 of Set 10 | aviles
# Processing Record 22 of Set 10 | skelleftea
# Processing Record 23 of Set 10 | sorong
# Processing Record 24 of Set 10 | bocaiuva
# Processing Record 25 of Set 10 | petrov val
# Processing Record 26 of Set 10 | wollongong
# Processing Record 27 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 10 | ust-maya
# Processing Record 29 of Set 10 | bubaque
# Processing Record 30 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 31 of Set 10 | necochea
# Processing Record 32 of Set 10 | sandwick
# Processing Record 33 of Set 10 | liapades
# City not found. Skipping...
# Processing Record 34 of Set 10 | kindersley
# Processing Record 35 of Set 10 | ossora
# Processing Record 36 of Set 10 | marsabit
# Processing Record 37 of Set 10 | san pedro de macoris
# Processing Record 38 of Set 10 | lavrentiya
# Processing Record 39 of Set 10 | elat
# Processing Record 40 of Set 10 | kamaishi
# Processing Record 41 of Set 10 | altamira
# Processing Record 42 of Set 10 | presidente medici
# Processing Record 43 of Set 10 | tocopilla
# Processing Record 44 of Set 10 | nemuro
# Processing Record 45 of Set 10 | jatiroto
# Processing Record 46 of Set 10 | port-gentil
# Processing Record 47 of Set 10 | catalina
# Processing Record 48 of Set 10 | inirida
# Processing Record 49 of Set 10 | soyo
# Processing Record 50 of Set 10 | avera
# Processing Record 1 of Set 11 | podosinovets
# Processing Record 2 of Set 11 | udarnyy
# Processing Record 3 of Set 11 | ambilobe
# Processing Record 4 of Set 11 | dwarka
# Processing Record 5 of Set 11 | gurupa
# Processing Record 6 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 7 of Set 11 | male
# Processing Record 8 of Set 11 | vostok
# Processing Record 9 of Set 11 | baoying
# Processing Record 10 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 11 | vestmannaeyjar
# Processing Record 12 of Set 11 | fleetwood
# Processing Record 13 of Set 11 | victoria
# Processing Record 14 of Set 11 | serenje
# Processing Record 15 of Set 11 | mahibadhoo
# Processing Record 16 of Set 11 | svetlaya
# Processing Record 17 of Set 11 | muli
# Processing Record 18 of Set 11 | rockport
# City not found. Skipping...
# Processing Record 19 of Set 11 | aswan
# City not found. Skipping...
# Processing Record 20 of Set 11 | xining
# City not found. Skipping...
# Processing Record 21 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 11 | eureka
# City not found. Skipping...
# Processing Record 23 of Set 11 | kuytun
# City not found. Skipping...
# Processing Record 24 of Set 11 | sao joao batista
# City not found. Skipping...
# Processing Record 25 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 11 | daund
# City not found. Skipping...
# Processing Record 27 of Set 11 | bairiki
# Processing Record 28 of Set 11 | gamba
# Processing Record 29 of Set 11 | evensk
# Processing Record 30 of Set 11 | talakan
# Processing Record 31 of Set 11 | san pedro
# Processing Record 32 of Set 11 | khatassy
# Processing Record 33 of Set 11 | andenes
# Processing Record 34 of Set 11 | hartselle
# Processing Record 35 of Set 11 | gataivai
# Processing Record 36 of Set 11 | winnemucca
# Processing Record 37 of Set 11 | leiyang
# Processing Record 38 of Set 11 | benguela
# Processing Record 39 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 11 | lewisville
# Processing Record 41 of Set 11 | tahta
# Processing Record 42 of Set 11 | agadez
# Processing Record 43 of Set 11 | xiongshi
# City not found. Skipping...
# Processing Record 44 of Set 11 | lavras
# Processing Record 45 of Set 11 | maniitsoq
# Processing Record 46 of Set 11 | palmas
# Processing Record 47 of Set 11 | gilgit
# Processing Record 48 of Set 11 | maniwaki
# Processing Record 49 of Set 11 | saint-augustin
# Processing Record 50 of Set 11 | yamada
# Processing Record 1 of Set 12 | puerto escondido
# Processing Record 2 of Set 12 | ust-barguzin
# Processing Record 3 of Set 12 | taltal
# Processing Record 4 of Set 12 | vallenar
# Processing Record 5 of Set 12 | namie
# Processing Record 6 of Set 12 | okhotsk
# Processing Record 7 of Set 12 | hovd
# Processing Record 8 of Set 12 | mansa
# Processing Record 9 of Set 12 | tessalit
# Processing Record 10 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 12 | ust-karsk
# Processing Record 12 of Set 12 | cangzhou
# Processing Record 13 of Set 12 | hirara
# Processing Record 14 of Set 12 | wakkanai
# Processing Record 15 of Set 12 | lakota
# Processing Record 16 of Set 12 | huarmey
# Processing Record 17 of Set 12 | sayat
# Processing Record 18 of Set 12 | pueblo nuevo
# Processing Record 19 of Set 12 | watertown
# Processing Record 20 of Set 12 | seoul
# Processing Record 21 of Set 12 | auki
# Processing Record 22 of Set 12 | cuamba
# Processing Record 23 of Set 12 | labrea
# Processing Record 24 of Set 12 | sao filipe
# Processing Record 25 of Set 12 | coffs harbour
# Processing Record 26 of Set 12 | hede
# Processing Record 27 of Set 12 | cloquet
# Processing Record 28 of Set 12 | guasdualito
# Processing Record 29 of Set 12 | muroto
# Processing Record 30 of Set 12 | guelengdeng
# City not found. Skipping...
# Processing Record 31 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 12 | plaster rock
# Processing Record 33 of Set 12 | chunskiy
# Processing Record 34 of Set 12 | vysha
# Processing Record 35 of Set 12 | baykit
# Processing Record 36 of Set 12 | rocha
# Processing Record 37 of Set 12 | gouyave
# Processing Record 38 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 12 | muros
# Processing Record 40 of Set 12 | pangai
# Processing Record 41 of Set 12 | gazli
# Processing Record 42 of Set 12 | dyakonovo
# City not found. Skipping...
# Processing Record 43 of Set 12 | dawlatabad
# Processing Record 44 of Set 12 | alamosa
# Processing Record 45 of Set 12 | marquette
# Processing Record 46 of Set 12 | khomutovka
# Processing Record 47 of Set 12 | barentu
# Processing Record 48 of Set 12 | fukue
# Processing Record 49 of Set 12 | arcachon
# Processing Record 50 of Set 12 | selikhino
# Processing Record 1 of Set 13 | jinchengjiang
# City not found. Skipping...
# Processing Record 2 of Set 13 | lukow
# Processing Record 3 of Set 13 | kurumkan
# Processing Record 4 of Set 13 | yumen
# Processing Record 5 of Set 13 | dakoro
# Processing Record 6 of Set 13 | akyab
# Processing Record 7 of Set 13 | inta
# Processing Record 8 of Set 13 | kjollefjord
# Processing Record 9 of Set 13 | zakamensk
# Processing Record 10 of Set 13 | umm lajj
# Processing Record 11 of Set 13 | bushenyi
# Processing Record 12 of Set 13 | champerico
# Processing Record 13 of Set 13 | sao joao nepomuceno
# Processing Record 14 of Set 13 | carauari
# Processing Record 15 of Set 13 | kendari
# Processing Record 16 of Set 13 | kuji
# Processing Record 17 of Set 13 | riyadh
# Processing Record 18 of Set 13 | nouadhibou
# Processing Record 19 of Set 13 | lagunas
# Processing Record 20 of Set 13 | guarapuava
# Processing Record 21 of Set 13 | lander
# Processing Record 22 of Set 13 | kedrovyy
# Processing Record 23 of Set 13 | killybegs
# Processing Record 24 of Set 13 | tete
# Processing Record 25 of Set 13 | gravdal
# Processing Record 26 of Set 13 | sinnamary
# Processing Record 27 of Set 13 | chumikan
# Processing Record 28 of Set 13 | yining
# Processing Record 29 of Set 13 | sebinkarahisar
# Processing Record 30 of Set 13 | yatou
# Processing Record 31 of Set 13 | mana
# Processing Record 32 of Set 13 | shenjiamen
# Processing Record 33 of Set 13 | conde
# Processing Record 34 of Set 13 | nurota
# Processing Record 35 of Set 13 | shimanovsk
# Processing Record 36 of Set 13 | jalu
# Processing Record 37 of Set 13 | kota belud
# Processing Record 38 of Set 13 | hazebrouck
# Processing Record 39 of Set 13 | shingu
# Processing Record 40 of Set 13 | nadvoitsy
# Processing Record 41 of Set 13 | qinhuangdao
# Processing Record 42 of Set 13 | baiyin
# Processing Record 43 of Set 13 | aksarka
# Processing Record 44 of Set 13 | ishigaki
# Processing Record 45 of Set 13 | wuwei
# Processing Record 46 of Set 13 | muravlenko
# Processing Record 47 of Set 13 | santiago del estero
# Processing Record 48 of Set 13 | shibetsu
# Processing Record 49 of Set 13 | kavieng
# Processing Record 50 of Set 13 | leshukonskoye
# Processing Record 1 of Set 14 | mogadishu
# Processing Record 2 of Set 14 | griffith
# Processing Record 3 of Set 14 | dongsheng
# Processing Record 4 of Set 14 | southbridge
# Processing Record 5 of Set 14 | gizo
# Processing Record 6 of Set 14 | kichmengskiy gorodok
# Processing Record 7 of Set 14 | tromso
# Processing Record 8 of Set 14 | lixourion
# Processing Record 9 of Set 14 | lakeway
# Processing Record 10 of Set 14 | kawalu
# Processing Record 11 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 14 | zhaotong
# Processing Record 13 of Set 14 | rimavska sobota
# Processing Record 14 of Set 14 | paita
# Processing Record 15 of Set 14 | teneguiban
# City not found. Skipping...
# Processing Record 16 of Set 14 | saint-nazaire
# Processing Record 17 of Set 14 | dabakala
# Processing Record 18 of Set 14 | khorol
# Processing Record 19 of Set 14 | trail
# Processing Record 20 of Set 14 | greven
# Processing Record 21 of Set 14 | sam chuk
# Processing Record 22 of Set 14 | oxelosund
# Processing Record 23 of Set 14 | raudeberg
# Processing Record 24 of Set 14 | labuhan
# Processing Record 25 of Set 14 | charters towers
# Processing Record 26 of Set 14 | dunn
# Processing Record 27 of Set 14 | mouzouras
# Processing Record 28 of Set 14 | dunmore town
# Processing Record 29 of Set 14 | barabinsk
# Processing Record 30 of Set 14 | santander
# Processing Record 31 of Set 14 | hamilton
# Processing Record 32 of Set 14 | puerto maldonado
# Processing Record 33 of Set 14 | sangar
# Processing Record 34 of Set 14 | cocachacra
# Processing Record 35 of Set 14 | inhambane
# Processing Record 36 of Set 14 | khilok
# Processing Record 37 of Set 14 | aquin
# Processing Record 38 of Set 14 | waharoa
# Processing Record 39 of Set 14 | careiro da varzea
# Processing Record 40 of Set 14 | plainview
# Processing Record 41 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 14 | sola
# Processing Record 43 of Set 14 | vanimo
# Processing Record 44 of Set 14 | yar-sale
# Processing Record 45 of Set 14 | moba
# Processing Record 46 of Set 14 | kavaratti
# Processing Record 47 of Set 14 | rio formoso
# Processing Record 48 of Set 14 | halmstad
# Processing Record 49 of Set 14 | concordia
# Processing Record 50 of Set 14 | sistranda
# Processing Record 1 of Set 15 | mehamn
# Processing Record 2 of Set 15 | atbasar
# Processing Record 3 of Set 15 | turukhansk
# Processing Record 4 of Set 15 | sabang
# Processing Record 5 of Set 15 | kisangani
# Processing Record 6 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 15 | jiuquan
# Processing Record 8 of Set 15 | oranjemund
# Processing Record 9 of Set 15 | camargo
# Processing Record 10 of Set 15 | selfoss
# Processing Record 11 of Set 15 | rovaniemi
# Processing Record 12 of Set 15 | abu samrah
# Processing Record 13 of Set 15 | srednekolymsk
# Processing Record 14 of Set 15 | ballina
# Processing Record 15 of Set 15 | tabuk
# Processing Record 16 of Set 15 | coulihaut
# City not found. Skipping...
# Processing Record 17 of Set 15 | katobu
# Processing Record 18 of Set 15 | tobermory
# Processing Record 19 of Set 15 | axim
# Processing Record 20 of Set 15 | sisimiut
# Processing Record 21 of Set 15 | brigantine
# Processing Record 22 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 15 | shubarkuduk
# Processing Record 24 of Set 15 | caborca
# Processing Record 25 of Set 15 | te anau
# Processing Record 26 of Set 15 | vawkavysk
# Processing Record 27 of Set 15 | abha
# Processing Record 28 of Set 15 | tornio
# Processing Record 29 of Set 15 | bondo
# Processing Record 30 of Set 15 | pedasi
# Processing Record 31 of Set 15 | ust-nera
# Processing Record 32 of Set 15 | bobcaygeon
# Processing Record 33 of Set 15 | mahon
# Processing Record 34 of Set 15 | okha
# Processing Record 35 of Set 15 | luwuk
# Processing Record 36 of Set 15 | celestun
# Processing Record 37 of Set 15 | poltava
# Processing Record 38 of Set 15 | tambacounda
# Processing Record 39 of Set 15 | bukama
# Processing Record 40 of Set 15 | college
# Processing Record 41 of Set 15 | tari
# Processing Record 42 of Set 15 | sorland
# Processing Record 43 of Set 15 | milingimbi
# City not found. Skipping...
# Processing Record 44 of Set 15 | weyburn
# Processing Record 45 of Set 15 | iznik
# Processing Record 46 of Set 15 | seminole
# Processing Record 47 of Set 15 | juba
# Processing Record 48 of Set 15 | kazachinskoye
# Processing Record 49 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 50 of Set 15 | eirunepe
# Processing Record 1 of Set 16 | dekar
# Processing Record 2 of Set 16 | miles city
# Processing Record 3 of Set 16 | tinaquillo
# Processing Record 4 of Set 16 | babanusah
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 688

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0         Thompson  55.7435  -97.8558     51.96       broken clouds        82
# 1           Sampit  -2.5333  112.9500     72.70     overcast clouds        97
# 2  Mnogovershinnyy  53.9353  139.9242     33.82     overcast clouds        71
# 3         Oussouye  12.4850  -16.5469     89.78     overcast clouds        81
# 4     Constitucion -35.3333  -72.4167     58.64       broken clouds        75
# 5          Iquitos  -3.7481  -73.2472     97.11     overcast clouds        37
# 6       Porto Novo   6.4965    2.6036     76.19     overcast clouds        86
# 7            Ancud -41.8697  -73.8203     53.11     overcast clouds        74
# 8      New Norfolk -42.7826  147.0587     39.70    scattered clouds        81
# 9     Kruisfontein -34.0033   24.7314     61.56     overcast clouds        87
#
#    Cloudiness  Wind Speed Country
# 0          75       12.66      CA
# 1          97        1.97      ID
# 2         100        3.06      RU
# 3         100        5.57      SN
# 4          64        5.91      CL
# 5         100        1.66      PE
# 6          97        7.27      BJ
# 7         100        5.77      CL
# 8          49        1.77      AU
# 9         100       11.32      ZA

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ['City', 'Country', 'Lat', 'Lng',
                            'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Thompson      CA  55.7435  -97.8558     51.96        82          75
# 1           Sampit      ID  -2.5333  112.9500     72.70        97          97
# 2  Mnogovershinnyy      RU  53.9353  139.9242     33.82        71         100
# 3         Oussouye      SN  12.4850  -16.5469     89.78        81         100
# 4     Constitucion      CL -35.3333  -72.4167     58.64        75          64
#
#    Wind Speed Current Description
# 0       12.66       broken clouds
# 1        1.97     overcast clouds
# 2        3.06     overcast clouds
# 3        5.57     overcast clouds
# 4        5.91       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
